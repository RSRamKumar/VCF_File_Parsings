# %%
import pandas as pd
import requests
import json

# %%
hpo_df = pd.read_csv('genes_to_phenotype_202203.txt', sep='\t', comment='#', header=None)
hpo_df.columns = ['entrez-gene-id',
                'entrez-gene-symbol', 
                'HPO-Term-ID', 
                'HPO-Term-Name',
                'Frequency-Raw', 
                'Frequency-HPO',
                'Additional Info from G-D source',
                'G-D source', 
                'disease-ID for link']
#print(hpo_df.head())

# %%
def parse_hpo_id_for_gene_symbol(gene_symbol):
    return hpo_df[hpo_df['entrez-gene-symbol'] == gene_symbol]['HPO-Term-ID'].to_list()

def parse_hpo_term_for_gene_symbol(gene_symbol):
    return hpo_df[hpo_df['entrez-gene-symbol'] == gene_symbol]['HPO-Term-Name'].to_list()

# %%
# getting hpo terms from varvis

def retrieve_hpo_terms_from_varvis(sample_id):
    hp_list=[]
    username='anthony.mackitz'
    passwd='User002#'

    r = requests.head("https://arcensus-diagnostics.varvis.com/authenticate")
    token = r.headers['X-CSRF-TOKEN']
    sessionId = r.cookies['session']

    r = requests.post("https://arcensus-diagnostics.varvis.com/login", data = {'_csrf': token, 'username': username, 'password': passwd}, cookies = dict(session=sessionId))
    sessionId = r.cookies['session']
    r = requests.head("https://arcensus-diagnostics.varvis.com/authenticate", cookies = dict(session=sessionId))


    hpor=requests.get("https://arcensus-diagnostics.varvis.com/api/person/"+sample_id, cookies = dict(session=sessionId))

    hpoj=json.loads(hpor.content)

    res=hpoj['response']['clinicalInformation']['hpoTerms']
    for i in res:
        #print(i)
        #hp_list.append((i['accession'], i['name'] ))
        hp_list.append( i['name'] )
    return hp_list

# %%
retrieve_hpo_terms_from_varvis('603703W1a')
# Out:
# ['Delayed speech and language development',
#  'Global developmental delay',
#  'Decreased body weight',
#  'Severe muscular hypotonia',
#  'Feeding difficulties']

# %%
 

master_STR_df = pd.read_excel('master_str_max_highlighted.xlsx')
required_columns = ['LOCUS'] + ['Pathogenic'] + [col for col in master_STR_df.columns if col.endswith('a')]

modified_master_STR_df = master_STR_df[required_columns]

# %%
modified_master_STR_df.head()
# Out:
#        LOCUS  Pathogenic  603703W1a  603730W1a  603733W1a  603736W1a  \
# 0       DAB1          31       13.0       13.0       13.0       17.0
# 1  NOTCH2NLC          90       11.0       16.0       17.0       19.0
# 2  NOTCH2NLC          60       11.0       16.0       17.0       19.0
# 3     STARD7         274       13.0       24.0       12.0       23.0
# 4     HOXD13          22        NaN        NaN        NaN        NaN
#
#    603742W1a  603744W1a  603749W1a  603753W1a  ...  704867W1a  704870W1a  \
# 0       12.0       13.0       12.0       14.0  ...       12.0       21.0
# 1       19.0       20.0       15.0       19.0  ...       12.0       25.0
# 2       19.0       20.0       15.0       19.0  ...       12.0       25.0
# 3       22.0       13.0       22.0       16.0  ...       14.0       13.0
# 4        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#    704874W1a  704878W1a  704881B1a  704886B1a  704887B1a  704888B1a  \
# 0       10.0       17.0       16.0       12.0       23.0       17.0
# 1       11.0       15.0       18.0       16.0       17.0       18.0
# 2       11.0       15.0       18.0       16.0       17.0       18.0
# 3        NaN       12.0       13.0        NaN       10.0       10.0
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#    704889B1a  704890B1a
# 0       28.0       14.0
# 1       20.0       15.0
# 2       20.0       15.0
# 3        NaN        NaN
# 4        NaN        NaN
#
# [5 rows x 289 columns]

# %%
def parsing_master_eh_file(sample_id):
    locus_list = set()
    for index,val in enumerate(modified_master_STR_df[sample_id]):
        if val >= modified_master_STR_df['Pathogenic'][index]:
            locus_list.add(modified_master_STR_df['LOCUS'][index])
    return locus_list

# %%
print(len( parsing_master_eh_file('704465W1a')))
# Out:
# 1

# %%
fout = open('hpo_varvis_match.csv', 'w')

# %%
for id in modified_master_STR_df.columns[2:]:
       print(id)
       locus_list = parsing_master_eh_file(id)

       if locus_list:
              varvis_hpo = retrieve_hpo_terms_from_varvis(id)
              for locus in locus_list:
                     #print(parse_hpo_term_for_gene_symbol(locus))
                     #print(locus, parse_hpo_term_for_gene_symbol(locus))
                     match = list(set(varvis_hpo).intersection(parse_hpo_term_for_gene_symbol(locus)))
                     fout.write('{};{};{};{}\n'.format(id,locus,match,len(match) ))
                     print(('{};{};{};{}\n'.format(id,locus,match,len(match) )))
fout.close()
        
                     

#https://stackoverflow.com/questions/2864842/common-elements-comparison-between-2-lists
# Out:
# 603703W1a
# 603703W1a;ARX_2;[];0
#
# 603730W1a
# 603730W1a;ARX_2;[];0
#
# 603730W1a;HOXA13_1;[];0
#
# 603733W1a
# 603733W1a;ARX_2;[];0
#
# 603736W1a
# 603736W1a;ARX_2;[];0
#
# 603736W1a;RUNX2;['Frontal bossing'];1
#
# 603742W1a
# 603742W1a;ARX_2;[];0
#
# 603742W1a;HOXA13_3;[];0
#
# 603744W1a
# 603744W1a;ARX_2;[];0
#
# 603749W1a
# 603749W1a;ARX_2;[];0
#
# 603753W1a
# 603760W1a
# 603760W1a;ARX_2;[];0
#
# 603763W1a
# 603763W1a;ARX_2;[];0
#
# 603763W1a;TCF4;['Seizure', 'Aggressive behavior'];2
#
# 603763W1a;RUNX2;[];0
#
# 603766W1a
# 603766W1a;RUNX2;[];0
#
# 603773W1a
# 603776W1a
# 603776W1a;ARX_2;[];0
#
# 603776W1a;HOXA13_1;[];0
#
# 603784W2a
# 603784W2a;ARX_2;[];0
#
# 603784W2a;HOXA13_3;[];0
#
# 603792W1a
# 603792W1a;ARX_2;[];0
#
# 603818W1a
# 603822W1a
# 603822W1a;ARX_2;[];0
#
# 603828W1a
# 603828W1a;ARX_2;[];0
#
# 603831W1a
# 603836W1a
# 603847W2a
# 603847W2a;ARX_1;[];0
#
# 603847W2a;HOXA13_3;[];0
#
# 603859W1a
# 603862W1a
# 603862W1a;ARX_2;[];0
#
# 603865W1a
# 603865W1a;ARX_2;[];0
#
# 603868W1a
# 603868W1a;ARX_2;[];0
#
# 603871W1a
# 603874W1a
# 603874W1a;ARX_2;[];0
#
# 603874W1a;HOXA13_3;[];0
#
# 603877W1a
# 603877W1a;HOXA13_3;[];0
#
# 603877W1a;RUNX2;[];0
#
# 603880W1a
# 603880W1a;ARX_2;[];0
#
# 603881W1a
# 603881W1a;ARX_2;[];0
#
# 603881W1a;HOXA13_1;[];0
#
# 603881W1a;HOXA13_3;[];0
#
# 603884W1a
# 603891W1a
# 603891W1a;ARX_2;[];0
#
# 603894W1a
# 603894W1a;HOXA13_1;[];0
#
# 603894W1a;HOXA13_3;[];0
#
# 603900W1a
# 603903W1a
# 603903W1a;HOXA13_3;[];0
#
# 603903W1a;RUNX2;[];0
#
# 603907W1a
# 603907W1a;ARX_2;[];0
#
# 603907W1a;RUNX2;[];0
#
# 603910W1a
# 603910W1a;DMD;['Global developmental delay'];1
#
# 603910W1a;HOXA13_3;[];0
#
# 603913W1a
# 603913W1a;ARX_2;[];0
#
# 603913W1a;RUNX2;[];0
#
# 603917W1a
# 603917W1a;ARX_2;[];0
#
# 603917W1a;ZIC3;[];0
#
# 603920W1a
# 603920W1a;HOXA13_3;[];0
#
# 603923W1a
# 603929W1a
# 603929W1a;ARX_2;[];0
#
# 603934W1a
# 603934W1a;ARX_2;[];0
#
# 603936W1a
# 603936W1a;ARX_2;[];0
#
# 603936W1a;HOXA13_3;[];0
#
# 603940W1a
# 603940W1a;ARX_2;[];0
#
# 603940W1a;HTT;[];0
#
# 604018W1a
# 604018W1a;ARX_2;[];0
#
# 604029W1a
# 604029W1a;ARX_2;[];0
#
# 604032W1a
# 604033W1a
# 604033W1a;ARX_2;[];0
#
# 604033W1a;HOXA13_1;[];0
#
# 604033W1a;HOXA13_3;[];0
#
# 604034W1a
# 604035W1a
# 604035W1a;HOXA13_2;[];0
#
# 604036W1a
# 604041W1a
# 604050W1a
# 604106W1a
# 604136W1a
# 604136W1a;ARX_2;[];0
#
# 604163W1a
# 604163W1a;ARX_2;[];0
#
# 604164W1a
# 604274W1a
# 604274W1a;ARX_2;[];0
#
# 604274W1a;RUNX2;[];0
#
# 604683W1a
# 604683W1a;HOXA13_3;[];0
#
# 604827W1a
# 604827W1a;TCF4;[];0
#
# 604827W1a;HOXA13_2;[];0
#
# 604827W1a;HOXA13_3;[];0
#
# 605225W1a
# 605225W1a;ARX_2;[];0
#
# 605254W1a
# 605254W1a;HOXA13_3;[];0
#
# 605257W1a
# 605257W1a;ARX_2;[];0
#
# 605257W1a;HOXA13_3;[];0
#
# 605263W1a
# 605263W1a;ARX_2;[];0
#
# 605263W1a;HOXA13_3;[];0
#
# 605326W1a
# 605326W1a;ARX_2;[];0
#
# 605326W1a;HOXA13_3;[];0
#
# 605377W1a
# 605386W1a
# 605386W1a;RUNX2;[];0
#
# 605388W1a
# 703968W1a
# 703968W1a;ARX_2;[];0
#
# 703968W1a;ATXN1;[];0
#
# 704351B1a
# 704351B1a;ARX_2;[];0
#
# 704352B1a
# 704352B1a;ARX_2;[];0
#
# 704353W1a
# 704353W1a;ARX_2;[];0
#
# 704354W1a
# 704354W1a;ARX_2;[];0
#
# 704354W1a;TCF4;[];0
#
# 704354W1a;HOXA13_2;[];0
#
# 704354W1a;HOXA13_3;[];0
#
# 704355W1a
# 704355W1a;TCF4;[];0
#
# 704356B1a
# 704356B1a;ARX_2;[];0
#
# 704358W1a
# 704358W1a;RUNX2;[];0
#
# 704359B1a
# 704359B1a;ARX_2;[];0
#
# 704359B1a;HOXA13_3;[];0
#
# 704360W1a
# 704360W1a;HOXA13_2;[];0
#
# 704361B1a
# 704361B1a;ARX_2;[];0
#
# 704362W1a
# 704363W1a
# 704364W1a
# 704365W1a
# 704365W1a;ARX_2;[];0
#
# 704366W1a
# 704366W1a;ARX_2;[];0
#
# 704366W1a;HOXA13_2;[];0
#
# 704367W1a
# 704367W1a;ARX_2;[];0
#
# 704368W1a
# 704369W1a
# 704370W1a
# 704372W1a
# 704372W1a;HOXA13_2;[];0
#
# 704372W1a;HOXA13_3;[];0
#
# 704373W1a
# 704373W1a;ARX_2;[];0
#
# 704375W1a
# 704375W1a;ARX_2;[];0
#
# 704377W1a
# 704377W1a;HOXA13_3;[];0
#
# 704377W1a;RUNX2;[];0
#
# 704383W1a
# 704383W1a;ARX_2;[];0
#
# 704383W1a;HOXA13_3;[];0
#
# 704384W1a
# 704384W1a;HOXA13_2;[];0
#
# 704384W1a;HOXA13_3;[];0
#
# 704385W1a
# 704385W1a;PRDM12;[];0
#
# 704400W1a
# 704401W1a
# 704401W1a;ARX_2;[];0
#
# 704401W1a;HOXA13_2;[];0
#
# 704402W1a
# 704402W1a;ARX_2;[];0
#
# 704405W1a
# 704405W1a;ARX_2;[];0
#
# 704405W1a;HOXA13_2;[];0
#
# 704407W1a
# 704407W1a;ARX_2;[];0
#
# 704407W1a;HOXA13_2;[];0
#
# 704408B1a
# 704408B1a;ARX_2;[];0
#
# 704408B1a;HOXA13_1;[];0
#
# 704411W1a
# 704413B1a
# 704413B1a;ARX_2;[];0
#
# 704414B1a
# 704418B1a
# 704424B1a
# 704424B1a;ARX_2;[];0
#
# 704424B1a;RUNX2;[];0
#
# 704427B1a
# 704427B1a;HOXA13_2;[];0
#
# 704431B1a
# 704433B1a
# 704435B1a
# 704435B1a;ARX_2;[];0
#
# 704437B1a
# 704439B1a
# 704439B1a;RUNX2;['Respiratory distress'];1
#
# 704443W1a
# 704443W1a;ARX_2;[];0
#
# 704443W1a;HOXA13_1;[];0
#
# 704443W1a;HOXA13_2;[];0
#
# 704443W1a;HOXA13_3;[];0
#
# 704445W1a
# 704445W1a;ARX_2;[];0
#
# 704445W1a;HOXA13_3;[];0
#
# 704446W1a
# 704446W1a;ARX_2;[];0
#
# 704447W1a
# 704447W1a;ARX_2;[];0
#
# 704448W1a
# 704448W1a;ARX_2;[];0
#
# 704448W1a;TCF4;['Hypotonia'];1
#
# 704448W1a;HOXA13_3;[];0
#
# 704449W1a
# 704449W1a;HOXA13_3;[];0
#
# 704450W1a
# 704450W1a;ARX_2;[];0
#
# 704451W1a
# 704451W1a;ATXN2;['Hypotonia'];1
#
# 704452W1a
# 704452W1a;ARX_2;[];0
#
# 704452W1a;DMD;[];0
#
# 704452W1a;RUNX2;[];0
#
# 704452W1a;HOXA13_2;[];0
#
# 704452W1a;HOXA13_3;[];0
#
# 704454W1a
# 704454W1a;RUNX2;[];0
#
# 704456W1a
# 704456W1a;HOXA13_1;[];0
#
# 704457W1a
# 704457W1a;ARX_2;[];0
#
# 704457W1a;HOXA13_3;[];0
#
# 704460W1a
# 704461W1a
# 704461W1a;ATXN8OS;[];0
#
# 704462W1a
# 704462W1a;ARX_2;[];0
#
# 704462W1a;HOXA13_3;[];0
#
# 704463W1a
# 704463W1a;HOXA13_3;[];0
#
# 704464W1a
# 704465W1a
# 704465W1a;HOXA13_2;[];0
#
# 704466W1a
# 704466W1a;HOXA13_1;[];0
#
# 704466W1a;HOXA13_3;[];0
#
# 704467W1a
# 704467W1a;HOXD13;[];0
#
# 704467W1a;HOXA13_3;[];0
#
# 704468W1a
# 704469W1a
# 704469W1a;ARX_2;[];0
#
# 704470W1a
# 704473W1a
# 704473W1a;ARX_2;[];0
#
# 704473W1a;DMD;[];0
#
# 704473W1a;HOXA13_3;[];0
#
# 704476W1a
# 704479W1a
# 704479W1a;RUNX2;['Macrocephaly'];1
#
# 704482W1a
# 704482W1a;TCF4;['Seizure', 'Aggressive behavior', 'Global developmental delay', 'Reduced visual acuity', 'Motor delay'];5
#
# 704482W1a;RUNX2;[];0
#
# 704485W1a
# 704485W1a;HOXA13_3;[];0
#
# 704488W1a
# 704488W1a;ARX_2;[];0
#
# 704488W1a;HOXA13_3;[];0
#
# 704492W1a
# 704492W1a;FOXL2;[];0
#
# 704497W1a
# 704497W1a;RUNX2;[];0
#
# 704500W1a
# 704501W1a
# 704501W1a;HOXA13_3;[];0
#
# 704501W1a;HOXA13_2;[];0
#
# 704501W1a;RUNX2;[];0
#
# 704502W1a
# 704503W1a
# 704503W1a;DMD;['Inability to walk', 'Delayed speech and language development', 'Global developmental delay'];3
#
# 704503W1a;HOXA13_3;[];0
#
# 704507W1a
# 704508W1a
# 704509W1a
# 704509W1a;HOXA13_2;[];0
#
# 704509W1a;HOXA13_3;[];0
#
# 704510B1a
# 704510B1a;RUNX2;[];0
#
# 704511B1a
# 704511B1a;RUNX2;[];0
#
# 704512B1a
# 704513B1a
# 704514B1a
# 704514B1a;DMPK;['Generalized hypotonia', 'Respiratory distress', 'Hypotonia'];3
#
# 704514B1a;RUNX2;['Respiratory distress'];1
#
# 704515W1a
# 704516W1a
# 704516W1a;TCF4;[];0
#
# 704516W1a;RUNX2;[];0
#
# 704517W1a
# 704518W1a
# 704519W1a
# 704519W1a;HOXA13_1;[];0
#
# 704519W1a;HOXA13_2;[];0
#
# 704520W1a
# 704520W1a;HOXA13_2;[];0
#
# 704520W1a;RUNX2;[];0
#
# 704522W1a
# 704522W1a;PRDM12;[];0
#
# 704522W1a;DMD;['Hypotonia', 'Global developmental delay'];2
#
# 704531W1a
# 704532W1a
# 704532W1a;RUNX2;[];0
#
# 704533W1a
# 704536W1a
# 704536W1a;RUNX2;[];0
#
# 704537W1a
# 704540W1a
# 704540W1a;TCF4;['Motor delay'];1
#
# 704540W1a;HOXA13_3;[];0
#
# 704541W1a
# 704541W1a;ARX_2;[];0
#
# 704541W1a;ARX_1;[];0
#
# 704543W1a
# 704545W1a
# 704548W1a
# 704548W1a;ARX_2;[];0
#
# 704552W1a
# 704552W1a;ARX_2;[];0
#
# 704556W1a
# 704556W1a;PRDM12;[];0
#
# 704556W1a;HOXA13_1;[];0
#
# 704556W1a;TCF4;['Seizure'];1
#
# 704559W1a
# 704559W1a;PRDM12;[];0
#
# 704561W1a
# 704561W1a;ARX_2;[];0
#
# 704563B1a
# 704564B1a
# 704564B1a;ARX_2;[];0
#
# 704565B1a
# 704566B1a
# 704567W1a
# 704569B1a
# 704570W1a
# 704571B1a
# 704571B1a;HOXA13_2;[];0
#
# 704571B1a;HOXA13_3;[];0
#
# 704572W1a
# 704572W1a;ARX_2;[];0
#
# 704572W1a;PABPN1;[];0
#
# 704573W1a
# 704574W1a
# 704575W1a
# 704576W1a
# 704576W1a;DMD;[];0
#
# 704577W1a
# 704577W1a;ARX_2;[];0
#
# 704577W1a;CACNA1A;[];0
#
# 704577W1a;HOXA13_1;[];0
#
# 704577W1a;HOXA13_3;[];0
#
# 704578W1a
# 704578W1a;ARX_2;[];0
#
# 704578W1a;HOXA13_3;[];0
#
# 704581W1a
# 704583B1a
# 704584W1a
# 704584W1a;HOXA13_3;[];0
#
# 704585B1a
# 704586B1a
# 704586B1a;RUNX2;[];0
#
# 704587B1a
# 704587B1a;ARX_2;[];0
#
# 704587B1a;HOXA13_3;[];0
#
# 704587B1a;HOXA13_2;[];0
#
# 704587B1a;RUNX2;[];0
#
# 704588B1a
# 704589W1a
# 704590B1a
# 704591W1a
# 704591W1a;HOXA13_1;[];0
#
# 704591W1a;HOXA13_2;[];0
#
# 704591W1a;HOXA13_3;[];0
#
# 704592B1a
# 704592B1a;HOXA13_1;[];0
#
# 704593W1a
# 704599B1a
# 704643W1a
# 704643W1a;PABPN1;[];0
#
# 704643W1a;RUNX2;[];0
#
# 704644W1a
# 704644W1a;ARX_2;[];0
#
# 704645B1a
# 704645B1a;ARX_2;[];0
#
# 704645B1a;HOXA13_1;[];0
#
# 704645B1a;HOXA13_2;[];0
#
# 704646B1a
# 704647B1a
# 704647B1a;HOXA13_1;[];0
#
# 704647B1a;HOXA13_2;[];0
#
# 704647B1a;HOXA13_3;[];0
#
# 704648W1a
# 704648W1a;NIPA1;[];0
#
# 704649W1a
# 704649W1a;ZIC2;[];0
#
# 704650W1a
# 704650W1a;ARX_2;[];0
#
# 704650W1a;RUNX2;['Macrocephaly'];1
#
# 704651W1a
# 704651W1a;ARX_2;[];0
#
# 704652W1a
# 704652W1a;ARX_2;[];0
#
# 704652W1a;ATXN8OS;[];0
#
# 704652W1a;ARX_1;[];0
#
# 704652W1a;HOXA13_3;[];0
#
# 704653W1a
# 704653W1a;ARX_2;[];0
#
# 704653W1a;ATXN8OS;[];0
#
# 704654W1a
# 704655W1a
# 704655W1a;RUNX2;[];0
#
# 704656W1a
# 704656W1a;ARX_2;[];0
#
# 704656W1a;HOXA13_2;[];0
#
# 704656W1a;HOXA13_3;[];0
#
# 704657W1a
# 704657W1a;SOX3;['Intellectual disability'];1
#
# 704658W1a
# 704660W1a
# 704665W1a
# 704667W1a
# 704667W1a;RUNX2;[];0
#
# 704668W1a
# 704669B1a
# 704669B1a;ARX_2;[];0
#
# 704669B1a;HOXA13_1;[];0
#
# 704669B1a;HOXA13_3;[];0
#
# 704670B1a
# 704670B1a;ARX_2;[];0
#
# 704670B1a;HOXA13_1;[];0
#
# 704670B1a;HOXA13_3;[];0
#
# 704671B1a
# 704671B1a;ARX_2;[];0
#
# 704678W1a
# 704678W1a;ARX_2;[];0
#
# 704679W1a
# 704679W1a;ARX_2;[];0
#
# 704680W1a
# 704719W1a
# 704719W1a;ARX_2;[];0
#
# 704719W1a;RUNX2;[];0
#
# 704723W2a
# 704723W2a;ARX_2;[];0
#
# 704726W2a
# 704726W2a;HOXA13_1;[];0
#
# 704726W2a;HOXA13_3;[];0
#
# 704730W1a
# 704730W1a;ARX_2;[];0
#
# 704732W2a
# 704732W2a;ARX_2;[];0
#
# 704732W2a;HOXA13_2;[];0
#
# 704732W2a;HOXA13_3;[];0
#
# 704736W2a
# 704736W2a;ARX_2;[];0
#
# 704739W2a
# 704739W2a;HOXA13_3;[];0
#
# 704742W2a
# 704742W2a;ARX_2;[];0
#
# 704742W2a;HOXA13_1;[];0
#
# 704742W2a;HOXA13_3;[];0
#
# 704745W1a
# 704749W1a
# 704749W1a;RUNX2;[];0
#
# 704750W2a
# 704750W2a;TCF4;['Seizure', 'Global developmental delay'];2
#
# 704754W1a
# 704754W1a;ARX_2;[];0
#
# 704757W1a
# 704757W1a;ARX_2;[];0
#
# 704757W1a;RUNX2;[];0
#
# 704762W1a
# 704762W1a;ARX_2;[];0
#
# 704762W1a;HOXA13_3;[];0
#
# 704765W1a
# 704767W1a
# 704767W1a;ARX_2;[];0
#
# 704767W1a;HOXA13_1;[];0
#
# 704768W1a
# 704768W1a;ARX_2;[];0
#
# 704769W1a
# 704769W1a;ARX_2;[];0
#
# 704770W1a
# 704770W1a;ARX_2;[];0
#
# 704771W1a
# 704771W1a;ARX_2;[];0
#
# 704772W1a
# 704772W1a;ARX_2;[];0
#
# 704773W1a
# 704773W1a;RUNX2;[];0
#
# 704809B1a
# 704809B1a;ARX_2;[];0
#
# 704809B1a;RUNX2;[];0
#
# 704810B1a
# 704810B1a;ARX_2;[];0
#
# 704810B1a;HOXA13_1;[];0
#
# 704810B1a;DMD;['Delayed speech and language development'];1
#
# 704810B1a;HOXA13_3;[];0
#
# 704811B1a
# 704811B1a;ARX_2;[];0
#
# 704812B1a
# 704812B1a;ARX_2;[];0
#
# 704813B1a
# 704813B1a;ARX_2;[];0
#
# 704814B1a
# 704814B1a;ARX_2;[];0
#
# 704815B1a
# 704815B1a;ARX_2;[];0
#
# 704815B1a;HOXA13_3;[];0
#
# 704817W2a
# 704817W2a;ARX_2;[];0
#
# 704817W2a;HOXA13_1;[];0
#
# 704817W2a;HOXA13_2;[];0
#
# 704819W2a
# 704819W2a;ARX_2;[];0
#
# 704819W2a;RUNX2;[];0
#
# 704821W2a
# 704821W2a;DMD;[];0
#
# 704821W2a;HOXA13_3;[];0
#
# 704823B1a
# 704823B1a;ARX_2;[];0
#
# 704826W2a
# 704827W1a
# 704828W2a
# 704828W2a;ARX_2;[];0
#
# 704829W1a
# 704829W1a;ARX_2;[];0
#
# 704829W1a;HOXA13_3;[];0
#
# 704831W1a
# 704831W1a;ARX_2;[];0
#
# 704834W2a
# 704834W2a;ARX_2;[];0
#
# 704834W2a;DMD;['Global developmental delay'];1
#
# 704835W2a
# 704835W2a;ARX_2;[];0
#
# 704835W2a;HOXA13_1;[];0
#
# 704846W2a
# 704846W2a;ARX_2;[];0
#
# 704846W2a;HOXA13_1;[];0
#
# 704846W2a;ARX_1;[];0
#
# 704846W2a;HOXA13_3;[];0
#
# 704849W1a
# 704852W1a
# 704852W1a;TCF4;[];0
#
# 704854W1a
# 704854W1a;ARX_2;[];0
#
# 704857W1a
# 704860W1a
# 704860W1a;HOXA13_2;[];0
#
# 704860W1a;HOXA13_3;[];0
#
# 704867W1a
# 704867W1a;HOXA13_3;[];0
#
# 704870W1a
# 704874W1a
# 704878W1a
# 704881B1a
# 704886B1a
# 704887B1a
# 704887B1a;ARX_2;[];0
#
# 704888B1a
# 704888B1a;ARX_2;[];0
#
# 704888B1a;RUNX2;[];0
#
# 704889B1a
# 704889B1a;ARX_2;[];0
#
# 704890B1a

# %%
hpo_varvis_df = pd.read_csv('hpo_varvis_match.csv', sep=';', header=None)
hpo_varvis_df.columns = ['sampleId','locus', 'matching_HPO_terms', 'count_of_matches']
print(hpo_varvis_df.head())
# Out:
#     sampleId     locus matching_HPO_terms  count_of_matches
# 0  603703W1a     ARX_2                 []                 0
# 1  603730W1a     ARX_2                 []                 0
# 2  603730W1a  HOXA13_1                 []                 0
# 3  603733W1a     ARX_2                 []                 0
# 4  603736W1a     ARX_2                 []                 0

# %%
hpo_varvis_df.shape
# Out:
# (327, 4)

# %%
observed_list = []
pathogenic_list = []
for index, row in hpo_varvis_df.iterrows():
    print(row['sampleId'], row['locus'])
    observed = modified_master_STR_df [modified_master_STR_df['LOCUS']==row['locus']][row['sampleId']].tolist()
    pathogenic = modified_master_STR_df [modified_master_STR_df['LOCUS']==row['locus']]['Pathogenic'].tolist()
    observed_list.append(set(observed))
    pathogenic_list.append(set(pathogenic))
    #print(observed)
    #print(pathogenic)
# Out:
# 603703W1a ARX_2
# 603730W1a ARX_2
# 603730W1a HOXA13_1
# 603733W1a ARX_2
# 603736W1a ARX_2
# 603736W1a RUNX2
# 603742W1a ARX_2
# 603742W1a HOXA13_3
# 603744W1a ARX_2
# 603749W1a ARX_2
# 603760W1a ARX_2
# 603763W1a ARX_2
# 603763W1a TCF4
# 603763W1a RUNX2
# 603766W1a RUNX2
# 603776W1a ARX_2
# 603776W1a HOXA13_1
# 603784W2a ARX_2
# 603784W2a HOXA13_3
# 603792W1a ARX_2
# 603822W1a ARX_2
# 603828W1a ARX_2
# 603847W2a ARX_1
# 603847W2a HOXA13_3
# 603862W1a ARX_2
# 603865W1a ARX_2
# 603868W1a ARX_2
# 603874W1a ARX_2
# 603874W1a HOXA13_3
# 603877W1a HOXA13_3
# 603877W1a RUNX2
# 603880W1a ARX_2
# 603881W1a ARX_2
# 603881W1a HOXA13_1
# 603881W1a HOXA13_3
# 603891W1a ARX_2
# 603894W1a HOXA13_1
# 603894W1a HOXA13_3
# 603903W1a HOXA13_3
# 603903W1a RUNX2
# 603907W1a ARX_2
# 603907W1a RUNX2
# 603910W1a DMD
# 603910W1a HOXA13_3
# 603913W1a ARX_2
# 603913W1a RUNX2
# 603917W1a ARX_2
# 603917W1a ZIC3
# 603920W1a HOXA13_3
# 603929W1a ARX_2
# 603934W1a ARX_2
# 603936W1a ARX_2
# 603936W1a HOXA13_3
# 603940W1a ARX_2
# 603940W1a HTT
# 604018W1a ARX_2
# 604029W1a ARX_2
# 604033W1a ARX_2
# 604033W1a HOXA13_1
# 604033W1a HOXA13_3
# 604035W1a HOXA13_2
# 604136W1a ARX_2
# 604163W1a ARX_2
# 604274W1a ARX_2
# 604274W1a RUNX2
# 604683W1a HOXA13_3
# 604827W1a TCF4
# 604827W1a HOXA13_2
# 604827W1a HOXA13_3
# 605225W1a ARX_2
# 605254W1a HOXA13_3
# 605257W1a ARX_2
# 605257W1a HOXA13_3
# 605263W1a ARX_2
# 605263W1a HOXA13_3
# 605326W1a ARX_2
# 605326W1a HOXA13_3
# 605386W1a RUNX2
# 703968W1a ARX_2
# 703968W1a ATXN1
# 704351B1a ARX_2
# 704352B1a ARX_2
# 704353W1a ARX_2
# 704354W1a ARX_2
# 704354W1a TCF4
# 704354W1a HOXA13_2
# 704354W1a HOXA13_3
# 704355W1a TCF4
# 704356B1a ARX_2
# 704358W1a RUNX2
# 704359B1a ARX_2
# 704359B1a HOXA13_3
# 704360W1a HOXA13_2
# 704361B1a ARX_2
# 704365W1a ARX_2
# 704366W1a ARX_2
# 704366W1a HOXA13_2
# 704367W1a ARX_2
# 704372W1a HOXA13_2
# 704372W1a HOXA13_3
# 704373W1a ARX_2
# 704375W1a ARX_2
# 704377W1a HOXA13_3
# 704377W1a RUNX2
# 704383W1a ARX_2
# 704383W1a HOXA13_3
# 704384W1a HOXA13_2
# 704384W1a HOXA13_3
# 704385W1a PRDM12
# 704401W1a ARX_2
# 704401W1a HOXA13_2
# 704402W1a ARX_2
# 704405W1a ARX_2
# 704405W1a HOXA13_2
# 704407W1a ARX_2
# 704407W1a HOXA13_2
# 704408B1a ARX_2
# 704408B1a HOXA13_1
# 704413B1a ARX_2
# 704424B1a ARX_2
# 704424B1a RUNX2
# 704427B1a HOXA13_2
# 704435B1a ARX_2
# 704439B1a RUNX2
# 704443W1a ARX_2
# 704443W1a HOXA13_1
# 704443W1a HOXA13_2
# 704443W1a HOXA13_3
# 704445W1a ARX_2
# 704445W1a HOXA13_3
# 704446W1a ARX_2
# 704447W1a ARX_2
# 704448W1a ARX_2
# 704448W1a TCF4
# 704448W1a HOXA13_3
# 704449W1a HOXA13_3
# 704450W1a ARX_2
# 704451W1a ATXN2
# 704452W1a ARX_2
# 704452W1a DMD
# 704452W1a RUNX2
# 704452W1a HOXA13_2
# 704452W1a HOXA13_3
# 704454W1a RUNX2
# 704456W1a HOXA13_1
# 704457W1a ARX_2
# 704457W1a HOXA13_3
# 704461W1a ATXN8OS
# 704462W1a ARX_2
# 704462W1a HOXA13_3
# 704463W1a HOXA13_3
# 704465W1a HOXA13_2
# 704466W1a HOXA13_1
# 704466W1a HOXA13_3
# 704467W1a HOXD13
# 704467W1a HOXA13_3
# 704469W1a ARX_2
# 704473W1a ARX_2
# 704473W1a DMD
# 704473W1a HOXA13_3
# 704479W1a RUNX2
# 704482W1a TCF4
# 704482W1a RUNX2
# 704485W1a HOXA13_3
# 704488W1a ARX_2
# 704488W1a HOXA13_3
# 704492W1a FOXL2
# 704497W1a RUNX2
# 704501W1a HOXA13_3
# 704501W1a HOXA13_2
# 704501W1a RUNX2
# 704503W1a DMD
# 704503W1a HOXA13_3
# 704509W1a HOXA13_2
# 704509W1a HOXA13_3
# 704510B1a RUNX2
# 704511B1a RUNX2
# 704514B1a DMPK
# 704514B1a RUNX2
# 704516W1a TCF4
# 704516W1a RUNX2
# 704519W1a HOXA13_1
# 704519W1a HOXA13_2
# 704520W1a HOXA13_2
# 704520W1a RUNX2
# 704522W1a PRDM12
# 704522W1a DMD
# 704532W1a RUNX2
# 704536W1a RUNX2
# 704540W1a TCF4
# 704540W1a HOXA13_3
# 704541W1a ARX_2
# 704541W1a ARX_1
# 704548W1a ARX_2
# 704552W1a ARX_2
# 704556W1a PRDM12
# 704556W1a HOXA13_1
# 704556W1a TCF4
# 704559W1a PRDM12
# 704561W1a ARX_2
# 704564B1a ARX_2
# 704571B1a HOXA13_2
# 704571B1a HOXA13_3
# 704572W1a ARX_2
# 704572W1a PABPN1
# 704576W1a DMD
# 704577W1a ARX_2
# 704577W1a CACNA1A
# 704577W1a HOXA13_1
# 704577W1a HOXA13_3
# 704578W1a ARX_2
# 704578W1a HOXA13_3
# 704584W1a HOXA13_3
# 704586B1a RUNX2
# 704587B1a ARX_2
# 704587B1a HOXA13_3
# 704587B1a HOXA13_2
# 704587B1a RUNX2
# 704591W1a HOXA13_1
# 704591W1a HOXA13_2
# 704591W1a HOXA13_3
# 704592B1a HOXA13_1
# 704643W1a PABPN1
# 704643W1a RUNX2
# 704644W1a ARX_2
# 704645B1a ARX_2
# 704645B1a HOXA13_1
# 704645B1a HOXA13_2
# 704647B1a HOXA13_1
# 704647B1a HOXA13_2
# 704647B1a HOXA13_3
# 704648W1a NIPA1
# 704649W1a ZIC2
# 704650W1a ARX_2
# 704650W1a RUNX2
# 704651W1a ARX_2
# 704652W1a ARX_2
# 704652W1a ATXN8OS
# 704652W1a ARX_1
# 704652W1a HOXA13_3
# 704653W1a ARX_2
# 704653W1a ATXN8OS
# 704655W1a RUNX2
# 704656W1a ARX_2
# 704656W1a HOXA13_2
# 704656W1a HOXA13_3
# 704657W1a SOX3
# 704667W1a RUNX2
# 704669B1a ARX_2
# 704669B1a HOXA13_1
# 704669B1a HOXA13_3
# 704670B1a ARX_2
# 704670B1a HOXA13_1
# 704670B1a HOXA13_3
# 704671B1a ARX_2
# 704678W1a ARX_2
# 704679W1a ARX_2
# 704719W1a ARX_2
# 704719W1a RUNX2
# 704723W2a ARX_2
# 704726W2a HOXA13_1
# 704726W2a HOXA13_3
# 704730W1a ARX_2
# 704732W2a ARX_2
# 704732W2a HOXA13_2
# 704732W2a HOXA13_3
# 704736W2a ARX_2
# 704739W2a HOXA13_3
# 704742W2a ARX_2
# 704742W2a HOXA13_1
# 704742W2a HOXA13_3
# 704749W1a RUNX2
# 704750W2a TCF4
# 704754W1a ARX_2
# 704757W1a ARX_2
# 704757W1a RUNX2
# 704762W1a ARX_2
# 704762W1a HOXA13_3
# 704767W1a ARX_2
# 704767W1a HOXA13_1
# 704768W1a ARX_2
# 704769W1a ARX_2
# 704770W1a ARX_2
# 704771W1a ARX_2
# 704772W1a ARX_2
# 704773W1a RUNX2
# 704809B1a ARX_2
# 704809B1a RUNX2
# 704810B1a ARX_2
# 704810B1a HOXA13_1
# 704810B1a DMD
# 704810B1a HOXA13_3
# 704811B1a ARX_2
# 704812B1a ARX_2
# 704813B1a ARX_2
# 704814B1a ARX_2
# 704815B1a ARX_2
# 704815B1a HOXA13_3
# 704817W2a ARX_2
# 704817W2a HOXA13_1
# 704817W2a HOXA13_2
# 704819W2a ARX_2
# 704819W2a RUNX2
# 704821W2a DMD
# 704821W2a HOXA13_3
# 704823B1a ARX_2
# 704828W2a ARX_2
# 704829W1a ARX_2
# 704829W1a HOXA13_3
# 704831W1a ARX_2
# 704834W2a ARX_2
# 704834W2a DMD
# 704835W2a ARX_2
# 704835W2a HOXA13_1
# 704846W2a ARX_2
# 704846W2a HOXA13_1
# 704846W2a ARX_1
# 704846W2a HOXA13_3
# 704852W1a TCF4
# 704854W1a ARX_2
# 704860W1a HOXA13_2
# 704860W1a HOXA13_3
# 704867W1a HOXA13_3
# 704887B1a ARX_2
# 704888B1a ARX_2
# 704888B1a RUNX2
# 704889B1a ARX_2

# %%
hpo_varvis_df['observed_str_count'] = observed_list
hpo_varvis_df['pathogenic_cutoff'] = pathogenic_list

# %%
hpo_varvis_df
# Out:
#       sampleId     locus matching_HPO_terms  count_of_matches  \
# 0    603703W1a     ARX_2                 []                 0
# 1    603730W1a     ARX_2                 []                 0
# 2    603730W1a  HOXA13_1                 []                 0
# 3    603733W1a     ARX_2                 []                 0
# 4    603736W1a     ARX_2                 []                 0
# ..         ...       ...                ...               ...
# 322  704867W1a  HOXA13_3                 []                 0
# 323  704887B1a     ARX_2                 []                 0
# 324  704888B1a     ARX_2                 []                 0
# 325  704888B1a     RUNX2                 []                 0
# 326  704889B1a     ARX_2                 []                 0
#
#     observed_str_count pathogenic_cutoff
# 0               {30.0}          {20, 23}
# 1               {57.0}          {20, 23}
# 2               {52.0}              {22}
# 3               {37.0}          {20, 23}
# 4               {64.0}          {20, 23}
# ..                 ...               ...
# 322             {50.0}              {24}
# 323             {40.0}          {20, 23}
# 324             {62.0}          {20, 23}
# 325             {56.0}              {27}
# 326             {38.0}          {20, 23}
#
# [327 rows x 6 columns]

# %%
hpo_varvis_df.to_excel('Final_Analyis_Expansion_Hunter.xlsx', index=False)
